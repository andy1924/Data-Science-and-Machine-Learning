# %%
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 47.1 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 45.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np

# %%
index = ['India', 'USA', 'China', 'Japan', 'Germany']
data = [1000, 2000, 3000, 4000, 5000]
ser = pd.Series(index = index, data = data)
ser
# Out:
# India      1000
# USA        2000
# China      3000
# Japan      4000
# Germany    5000
# dtype: int64

# %% [markdown]
# Series form a dictionary

# %%
dict = {'India': 1000, 'USA': 2000, 'China': 3000, 'Japan': 4000, 'Germany': 5000}
ser = pd.Series(dict)
ser
# Out:
# India      1000
# USA        2000
# China      3000
# Japan      4000
# Germany    5000
# dtype: int64

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1['Japan']
# Out:
# np.int64(80)

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
#Broadcasting in Pandas
#Normally [1,2]*2 = [1,2,1,2] but in Pandas it will multiply each element by 2
sales_q1 = sales_q1 * 2
sales_q1
# Out:
# Japan     320
# China    1800
# India     800
# USA      1000
# dtype: int64

# %%
totalSales= sales_q1 + sales_q2
totalSales
# Out:
# Brazil       NaN
# China     2300.0
# India     1010.0
# Japan        NaN
# USA       1260.0
# dtype: float64

# %%
sales_q1.add(sales_q2, fill_value=0)
# Out:
# Brazil     100.0
# China     2300.0
# India     1010.0
# Japan      320.0
# USA       1260.0
# dtype: float64

# %% [markdown]
# DATAFRAMES

# %%
np.random.seed(98)
data = np.random.randint(1, 100, (3,4))
data
# Out:
# array([[91, 43, 53, 64],
#        [92, 90, 66, 69],
#        [72, 39,  3, 24]])

# %%
index = ['MH', 'GJ', 'RJ']
columns = ['Jan', 'Feb', 'Mar', 'Apr']

# %%
df = pd.DataFrame(data = data , index = index, columns = columns)
df
# Out:
#     Jan  Feb  Mar  Apr
# MH   91   43   53   64
# GJ   92   90   66   69
# RJ   72   39    3   24

# %%
df.info
# Out:
# <bound method DataFrame.info of     Jan  Feb  Mar  Apr
# MH   91   43   53   64
# GJ   92   90   66   69
# RJ   72   39    3   24>

# %%
df = pd.read_csv('03-Pandas/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='str')

# %%
df.head() #gives first 5 rows of the data frame. You can also specify the number of rows you want to see by passing an integer value to the head() function. For example, df.head(10) will give you the first 10 rows of the data frame.
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    str
#  3   smoker            244 non-null    str
#  4   day               244 non-null    str
#  5   time              244 non-null    str
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    str
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    str
# dtypes: float64(3), int64(2), str(6)
# memory usage: 21.1 KB

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df = df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.iloc[0] #gives first 10 rows of the data frame. You can also specify the number of rows you want to see by passing an integer value to the iloc[] function. For example, df.iloc[0:10] will give you the first 10 rows of the data frame.
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc['Sun5260'] # gives the row with index 'Sun5260'. You can also use the loc[] function to select multiple rows by passing a list of index values. For example, df.loc[['Sun5260', 'Sun5261']] will give you the rows with index 'Sun5260' and 'Sun5261'.
# Out:
# total_bill                     23.68
# tip                             3.31
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               2
# price_per_person               11.84
# Payer Name          Nathaniel Harris
# CC Number           4676137647685994
# Name: Sun5260, dtype: object

# %% [markdown]
# Diffence between loc and iloc
# loc: “select by name”
# iloc: “select by number”

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.drop('Sun2959',axis = 0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
df.drop('smoker',axis=1)
# Out:
#             total_bill   tip     sex   day    time  size  price_per_person  \
# Payment ID
# Sun2959          16.99  1.01  Female   Sun  Dinner     2              8.49
# Sun4608          10.34  1.66    Male   Sun  Dinner     3              3.45
# Sun4458          21.01  3.50    Male   Sun  Dinner     3              7.00
# Sun5260          23.68  3.31    Male   Sun  Dinner     2             11.84
# Sun2251          24.59  3.61  Female   Sun  Dinner     4              6.15
# ...                ...   ...     ...   ...     ...   ...               ...
# Sat2657          29.03  5.92    Male   Sat  Dinner     3              9.68
# Sat1766          27.18  2.00  Female   Sat  Dinner     2             13.59
# Sat3880          22.67  2.00    Male   Sat  Dinner     2             11.34
# Sat17            17.82  1.75    Male   Sat  Dinner     2              8.91
# Thur672          18.78  3.00  Female  Thur  Dinner     2              9.39
#
#                     Payer Name         CC Number
# ...

# %%
df[df['smoker'] == 'Yes'] # gives all the rows where the value of the 'smoker' column is 'Yes'. You can also use the query() function to filter the data frame. For example, df.query('smoker == "Yes"') will give you the same result.
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sat8903          38.01  3.00    Male    Yes  Sat  Dinner     4
# Sat6683          11.24  1.76    Male    Yes  Sat  Dinner     2
# Sat2353          20.29  3.21    Male    Yes  Sat  Dinner     2
# Sat3030          13.81  2.00    Male    Yes  Sat  Dinner     2
# Sat2265          11.02  1.98    Male    Yes  Sat  Dinner     2
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat7220          15.53  3.00    Male    Yes  Sat  Dinner     2
# Sat5032          12.60  1.00    Male    Yes  Sat  Dinner     2
# Sat2929          32.83  1.17    Male    Yes  Sat  Dinner     2
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
#
#             price_per_person             Payer Name         CC Number
# Payment ID
# Sat8903                 9.50  James Christensen DDS   349793629453226
# ...

# %%
options = ['Sat' , 'Sun']
df[df['day'].isin(options)]# gives a boolean series indicating whether each row's 'day' value is in the options list. You can use this boolean series to filter the data frame. For example, df[df['day'].isin(options)] will give you all the rows where the 'day' value is either 'Sat' or 'Sun'.
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...
